# %% [markdown]
# ### **🧭 Stage 1 → Lesson 4: Importing & Exporting Data (I/O Operations)**
#
# **🎯 Objective**
#
# By the end of this lesson, you’ll:
#
# - Load data from various sources (CSV, Excel, JSON, SQL)
# - Handle file paths, encodings, missing headers
# - Export clean datasets in multiple formats
#  -Work with real data import/export patterns used in ETL

# %% [markdown]
# #### **🧱 Pandas I/O Ecosystem Overview**
#
# Pandas supports reading and writing 40+ data formats through its I/O API.
#
# | **Format**        | **Read Function**    | **Write Function**   |
# |-------------------|----------------------|----------------------|
# | CSV               | `read_csv()`         | `to_csv()`           |
# | Excel             | `read_excel()`       | `to_excel()`         |
# | JSON              | `read_json()`        | `to_json()`          |
# | Parquet           | `read_parquet()`     | `to_parquet()`       |
# | SQL               | `read_sql()`         | `to_sql()`           |
# | Clipboard         | `read_clipboard()`   | —                    |

# %% [markdown]
# **Importing necessary libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **🧩 Reading CSV Files**

# %%
# Since pandas is being used to handle the data, we assume it has already been imported. 
# If not, you can import it like this:
# import pandas as pd

# Step 2: Reading data from a CSV file
# pd.read_csv() is used to read a CSV file and load its contents into a pandas DataFrame.
# The 'r' before the file path is used to indicate a raw string, which ensures that backslashes in file paths are interpreted correctly.
df_SalesData = pd.read_csv(r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\sample_sales.csv")

# Step 3: Displaying the first few rows of the DataFrame
# .head() is a pandas function that returns the first 5 rows of the DataFrame by default. 
# This is useful for quickly inspecting the structure of the data, ensuring it's loaded correctly.
print(df_SalesData.head())
# Out:
#          Date     Product  Units  UnitPrice  Revenue
# 0  2024-01-01     Monitor     46       1999    91954
# 1  2024-01-02    Keyboard      8       9999    79992
# 2  2024-01-03  Headphones     25        999    24975
# 3  2024-01-04     Monitor     35      14999   524965
# 4  2024-01-05  Headphones     25       2999    74975

# %% [markdown]
# **Parameters for `read_csv()` and Other I/O Functions**
# | **Parameter**     | **Description**                              |
# |-------------------|----------------------------------------------|
# | `sep`             | Specify separator (default `,`)              |
# | `header`          | Row number(s) to use as the column names    |
# | `names`           | Custom column names (overrides header)      |
# | `index_col`       | Set column(s) to be used as index          |
# | `usecols`         | Load selected columns                       |
# | `nrows`           | Limit the number of rows to read           |
# | `encoding`        | Handle text encodings like `UTF-8`, `ISO-8859-1`, etc. |

# %%
print("Orifinal_Data:\n",df_SalesData.head())
# Out:
# Orifinal_Data:
#           Date     Product  Units  UnitPrice  Revenue
# 0  2024-01-01     Monitor     46       1999    91954
# 1  2024-01-02    Keyboard      8       9999    79992
# 2  2024-01-03  Headphones     25        999    24975
# 3  2024-01-04     Monitor     35      14999   524965
# 4  2024-01-05  Headphones     25       2999    74975

# %%
# Step 1: Defining the file path
# The path to the CSV file is defined as a raw string (r) to handle any backslashes in the file path correctly.
sales_data_path = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\sample_sales.csv"

# Step 2: Reading the CSV file with specific columns
# pd.read_csv() is used to read the data from the CSV file.
# The 'usecols' parameter specifies which columns to read from the CSV file.
# In this case, only the 'Product', 'Units', and 'Revenue' columns will be loaded into the DataFrame.
df_SalesData = pd.read_csv(sales_data_path, usecols=['Product', 'Units', 'Revenue'])

# Step 3: Displaying the first few rows of the DataFrame
# .head() returns the first 5 rows of the DataFrame, which is useful for verifying that the correct data has been loaded.
df_SalesData.head()
# Out:
#       Product  Units  Revenue
# 0     Monitor     46    91954
# 1    Keyboard      8    79992
# 2  Headphones     25    24975
# 3     Monitor     35   524965
# 4  Headphones     25    74975

# %% [markdown]
# **Handling Missing or Bad Data**

# %%
df = pd.read_csv(sales_data_path,na_values=['?','NA','Missing'])
df
# Out:
#            Date     Product  Units  UnitPrice  Revenue
# 0    2024-01-01     Monitor     46       1999    91954
# 1    2024-01-02    Keyboard      8       9999    79992
# 2    2024-01-03  Headphones     25        999    24975
# 3    2024-01-04     Monitor     35      14999   524965
# 4    2024-01-05  Headphones     25       2999    74975
# ..          ...         ...    ...        ...      ...
# 115  2024-04-25  Headphones     26       4999   129974
# 116  2024-04-26    Keyboard     42      14999   629958
# 117  2024-04-27      Laptop     22        999    21978
# 118  2024-04-28     Monitor     14       1999    27986
# 119  2024-04-29       Mouse      2       2999     5998
#
# [120 rows x 5 columns]

# %% [markdown]
# **Large File Optimization**

# %%
import pandas as pd

# Define the path to the Superstore Sales dataset using a raw string
superstore_sales = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\superstore_sales.csv"

# Try to read the CSV file in chunks, with error handling for possible issues
try:
    # Read the CSV file in chunks of 100 rows at a time using a different encoding (ISO-8859-1)
    # The 'ISO-8859-1' encoding is often used for files containing special characters in European languages.
    df_superstore = pd.read_csv(superstore_sales, encoding="ISO-8859-1", chunksize=100)

    # Iterate through each chunk of 100 rows and print the first 5 rows
    for data in df_superstore:
        print(data)  # Using .head() to display just the first 5 rows of each chunk

except FileNotFoundError:
    # If the file is not found, this block will catch it and print a custom error message
    print(f"The file at {superstore_sales} does not exist. Please check the file path.")

except Exception as e:
    # Catch any other unexpected errors and print them
    print(f"An error occurred: {e}")
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ..     ...             ...         ...         ...             ...
# 95      96  US-2017-109484   11/6/2017  11/12/2017  Standard Class
# 96      97  CA-2017-161018   11/9/2017  11/11/2017    Second Class
# 97      98  CA-2017-157833   6/17/2017   6/20/2017     First Class
# 98      99  CA-2016-149223    9/6/2016   9/11/2016  Standard Class
# 99     100  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
#
#    Customer ID      Customer Name      Segment        Country  \
# 0     CG-12520        Claire Gute     Consumer  United States
# 1     CG-12520        Claire Gute     Consumer  United States
# 2     DV-13045    Darrin Van Huff    Corporate  United States
# 3     SO-20335     Sean O'Donnell     Consumer  United States
# 4     SO-20335     Sean O'Donnell     Consumer  United States
# ..         ...                ...          ...            ...
# 95    RB-19705       Roger Barcio  Home Office  United States
# 96    PN-18775     Parhena Norris  Home Office  United States
# 97    KD-16345   Katherine Ducich     Consumer  United States
# 98    ER-13855  Elpida Rittenbach    Corporate  United States
# 99    RB-19465       Rick Bensley  Home Office  United States
#
#                City  ... Postal Code   Region       Product ID  \
# 0         Henderson  ...       42420    South  FUR-BO-10001798
# 1         Henderson  ...       42420    South  FUR-CH-10000454
# 2       Los Angeles  ...       90036     West  OFF-LA-10000240
# 3   Fort Lauderdale  ...       33311    South  FUR-TA-10000577
# 4   Fort Lauderdale  ...       33311    South  OFF-ST-10000760
# ..              ...  ...         ...      ...              ...
# 95         Portland  ...       97206     West  OFF-BI-10004738
# 96    New York City  ...       10009     East  FUR-FU-10000629
# 97    San Francisco  ...       94122     West  OFF-BI-10001721
# 98       Saint Paul  ...       55106  Central  OFF-AP-10000358
# 99          Chicago  ...       60610  Central  OFF-PA-10003256
#
#            Category Sub-Category  \
# 0         Furniture    Bookcases
# 1         Furniture       Chairs
# 2   Office Supplies       Labels
# 3         Furniture       Tables
# 4   Office Supplies      Storage
# ..              ...          ...
# 95  Office Supplies      Binders
# 96        Furniture  Furnishings
# 97  Office Supplies      Binders
# 98  Office Supplies   Appliances
# 99  Office Supplies        Paper
#
#                                          Product Name     Sales  Quantity  \
# 0                   Bush Somerset Collection Bookcase  261.9600         2
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2   Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3       Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                      Eldon Fold 'N Roll Cart System   22.3680         2
# ..                                                ...       ...       ...
# 95  Flexible Leather- Look Classic Collection Ring...    5.6820         1
# 96                    9-3/4 Diameter Round Wall Clock   96.5300         7
# 97                     Trimflex Flexible Post Binders   51.3120         3
# 98  Fellowes Basic Home/Office Series Surge Protec...   77.8800         6
# 99         Avery Personal Creations Heavyweight Cards   64.6240         7
#
#     Discount    Profit
# 0       0.00   41.9136
# 1       0.00  219.5820
# 2       0.00    6.8714
# 3       0.45 -383.0310
# 4       0.20    2.5164
# ..       ...       ...
# 95      0.70   -3.7880
# 96      0.00   40.5426
# 97      0.20   17.9592
# 98      0.00   22.5852
# 99      0.20   22.6184
#
# [100 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 100     101  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
# 101     102  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
# 102     103  CA-2016-129903   12/1/2016   12/4/2016    Second Class
# 103     104  US-2015-156867  11/13/2015  11/17/2015  Standard Class
# 104     105  US-2015-156867  11/13/2015  11/17/2015  Standard Class
# ..      ...             ...         ...         ...             ...
# 195     196  CA-2014-140004   3/21/2014   3/25/2014  Standard Class
# 196     197  CA-2014-140004   3/21/2014   3/25/2014  Standard Class
# 197     198  CA-2017-107720   11/6/2017  11/13/2017  Standard Class
# 198     199  US-2017-124303    7/6/2017   7/13/2017  Standard Class
# 199     200  US-2017-124303    7/6/2017   7/13/2017  Standard Class
#
#     Customer ID      Customer Name      Segment        Country          City  \
# 100    RB-19465       Rick Bensley  Home Office  United States       Chicago
# 101    RB-19465       Rick Bensley  Home Office  United States       Chicago
# 102    GZ-14470      Gary Zandusky     Consumer  United States     Rochester
# 103    LC-16870      Lena Cacioppo     Consumer  United States        Aurora
# 104    LC-16870      Lena Cacioppo     Consumer  United States        Aurora
# ..          ...                ...          ...            ...           ...
# 195    CB-12025  Cassandra Brandow     Consumer  United States      Hamilton
# 196    CB-12025  Cassandra Brandow     Consumer  United States      Hamilton
# 197    VM-21685    Valerie Mitchum  Home Office  United States     Westfield
# 198    FH-14365       Fred Hopkins    Corporate  United States  Philadelphia
# 199    FH-14365       Fred Hopkins    Corporate  United States  Philadelphia
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 100  ...       60610  Central  TEC-AC-10001767       Technology  Accessories
# 101  ...       60610  Central  OFF-BI-10002609  Office Supplies      Binders
# 102  ...       55901  Central  OFF-PA-10004040  Office Supplies        Paper
# 103  ...       80013     West  TEC-AC-10001552       Technology  Accessories
# 104  ...       80013     West  FUR-FU-10004006        Furniture  Furnishings
# ..   ...         ...      ...              ...              ...          ...
# 195  ...       45011     East  OFF-AR-10004685  Office Supplies          Art
# 196  ...       45011     East  OFF-AR-10004027  Office Supplies          Art
# 197  ...        7090     East  OFF-ST-10001414  Office Supplies      Storage
# 198  ...       19120     East  OFF-BI-10000343  Office Supplies      Binders
# 199  ...       19120     East  OFF-PA-10002749  Office Supplies        Paper
#
#                                           Product Name    Sales  Quantity  \
# 100  SanDisk Ultra 64 GB MicroSDHC Class 10 Memory ...   95.976         3
# 101      Avery Hidden Tab Dividers for Binding Systems    1.788         3
# 102  Universal Premium White Copier/Laser Paper (20...   23.920         4
# 103             Logitech K350 2.4Ghz Wireless Keyboard  238.896         6
# 104  Deflect-o DuraMat Lighweight, Studded, Beveled...  102.360         3
# ..                                                 ...      ...       ...
# 195  Binney & Smith Crayola Metallic Colored Pencil...    7.408         2
# 196  Binney & Smith inkTank Erasable Desk Highlight...    6.048         3
# 197              Decoflex Hanging Personal Folder File   46.260         3
# 198  Pressboard Covers with Storage Hooks, 9 1/2" x...    2.946         2
# 199  Wirebound Message Books, 5-1/2 x 4 Forms, 2 or...   16.056         3
#
#      Discount   Profit
# 100       0.2 -10.7973
# 101       0.8  -3.0396
# 102       0.0  11.7208
# 103       0.2 -26.8758
# 104       0.2  -3.8385
# ..        ...      ...
# 195       0.2   1.2038
# 196       0.2   1.5876
# 197       0.0  12.0276
# 198       0.7  -2.2586
# 199       0.2   5.8203
#
# [100 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 200     201  CA-2017-105074   6/24/2017   6/29/2017  Standard Class
# 201     202  CA-2014-133690    8/3/2014    8/5/2014     First Class
# 202     203  CA-2014-133690    8/3/2014    8/5/2014     First Class
# 203     204  US-2017-116701  12/17/2017  12/21/2017    Second Class
# 204     205  CA-2017-126382    6/3/2017    6/7/2017  Standard Class
# ..      ...             ...         ...         ...             ...
# 295     296  CA-2014-111451  12/26/2014  12/28/2014     First Class
# 296     297  CA-2014-111451  12/26/2014  12/28/2014     First Class
# 297     298  CA-2014-111451  12/26/2014  12/28/2014     First Class
# 298     299  CA-2016-142545  10/28/2016   11/3/2016  Standard Class
# 299     300  CA-2016-142545  10/28/2016   11/3/2016  Standard Class
#
#     Customer ID     Customer Name    Segment        Country              City  \
# 200    MB-17305   Maria Bertelson   Consumer  United States             Akron
# 201    BS-11755     Bruce Stewart   Consumer  United States            Denver
# 202    BS-11755     Bruce Stewart   Consumer  United States            Denver
# 203    LC-17140      Logan Currie   Consumer  United States            Dallas
# 204    HK-14890  Heather Kirkland  Corporate  United States          Franklin
# ..          ...               ...        ...            ...               ...
# 295    KL-16555     Kelly Lampkin  Corporate  United States  Colorado Springs
# 296    KL-16555     Kelly Lampkin  Corporate  United States  Colorado Springs
# 297    KL-16555     Kelly Lampkin  Corporate  United States  Colorado Springs
# 298    JD-15895  Jonathan Doherty  Corporate  United States        Belleville
# 299    JD-15895  Jonathan Doherty  Corporate  United States        Belleville
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 200  ...       44312     East  OFF-PA-10002666  Office Supplies        Paper
# 201  ...       80219     West  FUR-TA-10004289        Furniture       Tables
# 202  ...       80219     West  OFF-AP-10003622  Office Supplies   Appliances
# 203  ...       75220  Central  OFF-AP-10003217  Office Supplies   Appliances
# 204  ...       37064    South  FUR-FU-10002960        Furniture  Furnishings
# ..   ...         ...      ...              ...              ...          ...
# 295  ...       80906     West  FUR-FU-10002918        Furniture  Furnishings
# 296  ...       80906     West  OFF-BI-10004593  Office Supplies      Binders
# 297  ...       80906     West  OFF-FA-10004854  Office Supplies    Fasteners
# 298  ...        7109     East  OFF-PA-10002105  Office Supplies        Paper
# 299  ...        7109     East  OFF-ST-10002756  Office Supplies      Storage
#
#                                           Product Name     Sales  Quantity  \
# 200  Southworth 25% Cotton Linen-Finish Paper & Env...    21.744         3
# 201  BoxOffice By Design Rectangular and Half-Moon ...   218.750         2
# 202  Bravo II Megaboss 12-Amp Hard Body Upright, Re...     2.600         1
# 203               Eureka Sanitaire  Commercial Upright    66.284         2
# 204         Eldon 200 Class Desk Accessories, Burgundy    35.168         7
# ..                                                 ...       ...       ...
# 295  Eldon ClusterMat Chair Mat with Cordless Antis...   218.352         3
# 296      Ibico Laser Imprintable Binding System Covers    78.600         5
# 297  Vinyl Coated Wire Paper Clips in Organizer Box...    27.552         3
# 298                                          Xerox 223    32.400         5
# 299  Tennsco Stur-D-Stor Boltless Shelving, 5 Shelv...  1082.480         8
#
#      Discount    Profit
# 200       0.2    6.7950
# 201       0.5 -161.8750
# 202       0.2    0.2925
# 203       0.8 -178.9668
# 204       0.2    9.6712
# ..        ...       ...
# 295       0.2  -24.5646
# 296       0.7  -62.8800
# 297       0.2    9.2988
# 298       0.0   15.5520
# 299       0.0   10.8248
#
# [100 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 300     301  CA-2016-142545  10/28/2016   11/3/2016  Standard Class
# 301     302  CA-2016-142545  10/28/2016   11/3/2016  Standard Class
# 302     303  CA-2016-142545  10/28/2016   11/3/2016  Standard Class
# 303     304  US-2017-152380  11/19/2017  11/23/2017  Standard Class
# 304     305  CA-2015-144253    5/4/2015    5/9/2015    Second Class
# ..      ...             ...         ...         ...             ...
# 395     396  CA-2017-165603  10/17/2017  10/19/2017    Second Class
# 396     397  CA-2017-165603  10/17/2017  10/19/2017    Second Class
# 397     398  CA-2015-122259  10/31/2015   11/4/2015  Standard Class
# 398     399  CA-2016-108987    9/8/2016   9/10/2016    Second Class
# 399     400  CA-2016-108987    9/8/2016   9/10/2016    Second Class
#
#     Customer ID      Customer Name      Segment        Country           City  \
# 300    JD-15895   Jonathan Doherty    Corporate  United States     Belleville
# 301    JD-15895   Jonathan Doherty    Corporate  United States     Belleville
# 302    JD-15895   Jonathan Doherty    Corporate  United States     Belleville
# 303    JH-15910    Jonathan Howell     Consumer  United States        Chicago
# 304    AS-10225  Alan Schoenberger    Corporate  United States  New York City
# ..          ...                ...          ...            ...            ...
# 395    SS-20140   Saphhira Shifley    Corporate  United States        Warwick
# 396    SS-20140   Saphhira Shifley    Corporate  United States        Warwick
# 397    HP-14815      Harold Pawlan  Home Office  United States        Jackson
# 398    AG-10675        Anna Gayman     Consumer  United States        Houston
# 399    AG-10675        Anna Gayman     Consumer  United States        Houston
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 300  ...        7109     East  OFF-PA-10004243  Office Supplies        Paper
# 301  ...        7109     East  FUR-FU-10001861        Furniture  Furnishings
# 302  ...        7109     East  OFF-BI-10002706  Office Supplies      Binders
# 303  ...       60623  Central  FUR-TA-10002533        Furniture       Tables
# 304  ...       10024     East  FUR-FU-10002671        Furniture  Furnishings
# ..   ...         ...      ...              ...              ...          ...
# 395  ...        2886     East  OFF-ST-10000798  Office Supplies      Storage
# 396  ...        2886     East  OFF-PA-10002552  Office Supplies        Paper
# 397  ...       49201  Central  OFF-SU-10002573  Office Supplies     Supplies
# 398  ...       77036  Central  OFF-ST-10001580  Office Supplies      Storage
# 399  ...       77036  Central  FUR-BO-10004834        Furniture    Bookcases
#
#                                           Product Name      Sales  Quantity  \
# 300                                         Xerox 1939    56.9100         3
# 301  Floodlight Indoor Halogen Bulbs, 1 Bulb per Pa...    77.6000         4
# 302  Avery Premier Heavy-Duty Binder with Round Loc...    14.2800         1
# 303                              BPI Conference Tables   219.0750         3
# 304  Electrix 20W Halogen Replacement Bulb for Zoom...    26.8000         2
# ..                                                 ...        ...       ...
# 395     2300 Heavy-Duty Transfer File Systems by Perma    49.9600         2
# 396                                         Xerox 1958    12.9600         2
# 397              Acme 10" Easy Grip Assistive Scissors    70.1200         4
# 398              Super Decoflex Portable Personal File    35.9520         3
# 399  Riverside Palais Royal Lawyers Bookcase, Royal...  2396.2656         4
#
#      Discount    Profit
# 300      0.00   27.3168
# 301      0.00   38.0240
# 302      0.00    6.5688
# 303      0.50 -131.4450
# 304      0.00   12.8640
# ..        ...       ...
# 395      0.00    9.4924
# 396      0.00    6.2208
# 397      0.00   21.0360
# 398      0.20    3.5952
# 399      0.32 -317.1528
#
# [100 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 400     401  CA-2016-108987    9/8/2016   9/10/2016    Second Class
# 401     402  CA-2016-108987    9/8/2016   9/10/2016    Second Class
# 402     403  CA-2014-113166  12/24/2014  12/26/2014     First Class
# 403     404  CA-2014-155208   4/16/2014   4/20/2014  Standard Class
# 404     405  CA-2017-117933  12/24/2017  12/29/2017  Standard Class
# ..      ...             ...         ...         ...             ...
# 495     496  CA-2015-134782  12/27/2015  12/31/2015  Standard Class
# 496     497  CA-2016-126158   7/25/2016   7/31/2016  Standard Class
# 497     498  CA-2016-126158   7/25/2016   7/31/2016  Standard Class
# 498     499  CA-2016-126158   7/25/2016   7/31/2016  Standard Class
# 499     500  CA-2016-126158   7/25/2016   7/31/2016  Standard Class
#
#     Customer ID     Customer Name    Segment        Country           City  \
# 400    AG-10675       Anna Gayman   Consumer  United States        Houston
# 401    AG-10675       Anna Gayman   Consumer  United States        Houston
# 402    LF-17185       Luke Foster   Consumer  United States          Miami
# 403    SP-20650  Stephanie Phelps  Corporate  United States     Wilmington
# 404    RF-19840   Roy Französisch   Consumer  United States  New York City
# ..          ...               ...        ...            ...            ...
# 495    MD-17350     Maribeth Dona   Consumer  United States   Fayetteville
# 496    SC-20095      Sanjit Chand   Consumer  United States     Costa Mesa
# 497    SC-20095      Sanjit Chand   Consumer  United States     Costa Mesa
# 498    SC-20095      Sanjit Chand   Consumer  United States     Costa Mesa
# 499    SC-20095      Sanjit Chand   Consumer  United States     Costa Mesa
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 400  ...       77036  Central  OFF-ST-10000934  Office Supplies      Storage
# 401  ...       77036  Central  TEC-AC-10000158       Technology  Accessories
# 402  ...       33180    South  OFF-PA-10001947  Office Supplies        Paper
# 403  ...       28403    South  OFF-AR-10003478  Office Supplies          Art
# 404  ...       10024     East  OFF-AP-10004249  Office Supplies   Appliances
# ..   ...         ...      ...              ...              ...          ...
# 495  ...       72701    South  OFF-EN-10001434  Office Supplies    Envelopes
# 496  ...       92627     West  OFF-BI-10002498  Office Supplies      Binders
# 497  ...       92627     West  FUR-FU-10004864        Furniture  Furnishings
# 498  ...       92627     West  FUR-CH-10002602        Furniture       Chairs
# 499  ...       92627     West  FUR-FU-10000073        Furniture  Furnishings
#
#                                           Product Name    Sales  Quantity  \
# 400             Contico 72"H Heavy-Duty Storage System  131.136         4
# 401      Sony 64GB Class 10 Micro SDHC R40 Memory Card   57.584         2
# 402                                         Xerox 1974    9.568         2
# 403  Avery Hi-Liter EverBold Pen Style Fluorescent ...   39.072         6
# 404                                      Staple holder   35.910         3
# ..                                                 ...      ...       ...
# 495           Strathmore #10 Envelopes, Ultimate White  105.420         2
# 496                     Clear Mylar Reinforcing Strips  119.616         8
# 497  Howard Miller 14-1/2" Diameter Chrome Round Wa...  255.760         4
# 498  DMI Arturo Collection Mission-style Design Woo...  241.568         2
# 499        Deflect-O Glasstique Clear Desk Accessories   69.300         9
#
#      Discount   Profit
# 400       0.2 -32.7840
# 401       0.2   0.7198
# 402       0.2   3.4684
# 403       0.2   9.7680
# 404       0.0   9.6957
# ..        ...      ...
# 495       0.0  51.6558
# 496       0.2  40.3704
# 497       0.0  81.8432
# 498       0.2  18.1176
# 499       0.0  22.8690
#
# [100 rows x 21 columns]
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 500     501  US-2016-105578  5/30/2016   6/4/2016  Standard Class    MY-17380
# 501     502  US-2016-105578  5/30/2016   6/4/2016  Standard Class    MY-17380
# 502     503  US-2016-105578  5/30/2016   6/4/2016  Standard Class    MY-17380
# 503     504  US-2016-105578  5/30/2016   6/4/2016  Standard Class    MY-17380
# 504     505  US-2016-105578  5/30/2016   6/4/2016  Standard Class    MY-17380
# ..      ...             ...        ...        ...             ...         ...
# 595     596  CA-2014-131450   8/8/2014  8/15/2014  Standard Class    LR-16915
# 596     597  CA-2014-131450   8/8/2014  8/15/2014  Standard Class    LR-16915
# 597     598  CA-2014-131450   8/8/2014  8/15/2014  Standard Class    LR-16915
# 598     599  CA-2016-120180  7/14/2016  7/16/2016     First Class    TP-21130
# 599     600  US-2016-100720  7/16/2016  7/21/2016  Standard Class    CK-12205
#
#            Customer Name    Segment        Country          City  ...  \
# 500      Maribeth Yedwab  Corporate  United States        Parker  ...
# 501      Maribeth Yedwab  Corporate  United States        Parker  ...
# 502      Maribeth Yedwab  Corporate  United States        Parker  ...
# 503      Maribeth Yedwab  Corporate  United States        Parker  ...
# 504      Maribeth Yedwab  Corporate  United States        Parker  ...
# ..                   ...        ...            ...           ...  ...
# 595         Lena Radford   Consumer  United States     San Diego  ...
# 596         Lena Radford   Consumer  United States     San Diego  ...
# 597         Lena Radford   Consumer  United States     San Diego  ...
# 598     Theone Pippenger   Consumer  United States  Philadelphia  ...
# 599  Chloris Kastensmidt   Consumer  United States  Philadelphia  ...
#
#     Postal Code  Region       Product ID         Category Sub-Category  \
# 500       80134    West  OFF-BI-10001670  Office Supplies      Binders
# 501       80134    West  OFF-BI-10001658  Office Supplies      Binders
# 502       80134    West  FUR-CH-10001215        Furniture       Chairs
# 503       80134    West  OFF-BI-10000831  Office Supplies      Binders
# 504       80134    West  OFF-PA-10000357  Office Supplies        Paper
# ..          ...     ...              ...              ...          ...
# 595       92024    West  TEC-CO-10004115       Technology      Copiers
# 596       92024    West  TEC-PH-10002398       Technology       Phones
# 597       92024    West  FUR-FU-10001979        Furniture  Furnishings
# 598       19134    East  OFF-SU-10004115  Office Supplies     Supplies
# 599       19120    East  TEC-PH-10001425       Technology       Phones
#
#                                           Product Name     Sales  Quantity  \
# 500                       Vinyl Sectional Post Binders    22.620         2
# 501                   GBC Standard Therm-A-Bind Covers    14.952         2
# 502      Global Troy Executive Leather Low-Back Tilter   801.568         2
# 503   Storex Flexible Poly Binders with Double Pockets     2.376         3
# 504  White Dual Perf Computer Printout Paper, 2700 ...    32.792         1
# ..                                                 ...       ...       ...
# 595                     Sharp AL-1530CS Digital Copier  1199.976         3
# 596                             AT&T 1070 Corded Phone   445.960         5
# 597              Dana Halogen Swing-Arm Architect Lamp   327.760         8
# 598                  Acme Stainless Steel Office Snips    11.632         2
# 599                Mophie Juice Pack Helium for iPhone   143.982         3
#
#      Discount    Profit
# 500       0.7  -15.0800
# 501       0.7  -11.9616
# 502       0.2   50.0980
# 503       0.7   -1.9008
# 504       0.2   11.8871
# ..        ...       ...
# 595       0.2  434.9913
# 596       0.2   55.7450
# 597       0.0   91.7728
# 598       0.2    1.0178
# 599       0.4  -28.7964
#
# [100 rows x 21 columns]
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 600     601  US-2016-100720  7/16/2016  7/21/2016  Standard Class    CK-12205
# 601     602  US-2016-100720  7/16/2016  7/21/2016  Standard Class    CK-12205
# 602     603  CA-2014-149958  3/15/2014  3/19/2014  Standard Class    AS-10240
# 603     604  CA-2014-149958  3/15/2014  3/19/2014  Standard Class    AS-10240
# 604     605  CA-2014-149958  3/15/2014  3/19/2014  Standard Class    AS-10240
# ..      ...             ...        ...        ...             ...         ...
# 695     696  CA-2015-119291  5/14/2015  5/17/2015     First Class    JO-15550
# 696     697  CA-2015-119291  5/14/2015  5/17/2015     First Class    JO-15550
# 697     698  CA-2015-119291  5/14/2015  5/17/2015     First Class    JO-15550
# 698     699  CA-2015-119291  5/14/2015  5/17/2015     First Class    JO-15550
# 699     700  CA-2015-119291  5/14/2015  5/17/2015     First Class    JO-15550
#
#            Customer Name      Segment        Country          City  ...  \
# 600  Chloris Kastensmidt     Consumer  United States  Philadelphia  ...
# 601  Chloris Kastensmidt     Consumer  United States  Philadelphia  ...
# 602         Alan Shonely     Consumer  United States         Tampa  ...
# 603         Alan Shonely     Consumer  United States         Tampa  ...
# 604         Alan Shonely     Consumer  United States         Tampa  ...
# ..                   ...          ...            ...           ...  ...
# 695         Jesus Ocampo  Home Office  United States       Chester  ...
# 696         Jesus Ocampo  Home Office  United States       Chester  ...
# 697         Jesus Ocampo  Home Office  United States       Chester  ...
# 698         Jesus Ocampo  Home Office  United States       Chester  ...
# 699         Jesus Ocampo  Home Office  United States       Chester  ...
#
#     Postal Code  Region       Product ID         Category Sub-Category  \
# 600       19120    East  TEC-PH-10003963       Technology       Phones
# 601       19120    East  OFF-SU-10001574  Office Supplies     Supplies
# 602       33614   South  OFF-ST-10001490  Office Supplies      Storage
# 603       33614   South  FUR-FU-10001756        Furniture  Furnishings
# 604       33614   South  OFF-BI-10000773  Office Supplies      Binders
# ..          ...     ...              ...              ...          ...
# 695       19013    East  OFF-LA-10002312  Office Supplies       Labels
# 696       19013    East  OFF-EN-10000927  Office Supplies    Envelopes
# 697       19013    East  OFF-LA-10003510  Office Supplies       Labels
# 698       19013    East  OFF-AR-10001118  Office Supplies          Art
# 699       19013    East  OFF-BI-10001575  Office Supplies      Binders
#
#                                           Product Name    Sales  Quantity  \
# 600                      GE 2-Jack Phone Line Splitter  494.376         4
# 601                           Acme Value Line Scissors    5.840         2
# 602                     Hot File 7-Pocket, Floor Stand  142.776         1
# 603  Eldon Expressions Desk Accessory, Wood Photo F...   45.696         3
# 604                Insertable Tab Post Binder Dividers    7.218         3
# ..                                                 ...      ...       ...
# 695                                          Avery 490   47.360         4
# 696      Jet-Pak Recycled Peel 'N' Seal Padded Mailers  200.984         7
# 697  Avery 4027 File Folder Labels for Dot Matrix P...   97.696         4
# 698  Binney & Smith Crayola Metallic Crayons, 16-Co...    2.696         1
# 699                           GBC Linen Binding Covers   18.588         2
#
#      Discount    Profit
# 600       0.4 -115.3544
# 601       0.2    0.7300
# 602       0.2   17.8470
# 603       0.2    5.1408
# 604       0.7   -5.5338
# ..        ...       ...
# 695       0.2   17.7600
# 696       0.2   62.8075
# 697       0.2   31.7512
# 698       0.2    0.8088
# 699       0.7  -13.6312
#
# [100 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 700     701  CA-2015-119291   5/14/2015   5/17/2015     First Class
# 701     702  CA-2017-114552    9/2/2017    9/8/2017  Standard Class
# 702     703  CA-2016-163755   11/4/2016   11/8/2016    Second Class
# 703     704  CA-2015-142027    4/9/2015   4/14/2015  Standard Class
# 704     705  CA-2014-138527   9/12/2014   9/17/2014  Standard Class
# ..      ...             ...         ...         ...             ...
# 795     796  CA-2017-151428   9/21/2017   9/26/2017  Standard Class
# 796     797  CA-2015-124653  12/24/2015  12/26/2015     First Class
# 797     798  CA-2015-124653  12/24/2015  12/26/2015     First Class
# 798     799  CA-2015-124653  12/24/2015  12/26/2015     First Class
# 799     800  CA-2015-101910  11/27/2015   12/3/2015  Standard Class
#
#     Customer ID     Customer Name      Segment        Country           City  \
# 700    JO-15550      Jesus Ocampo  Home Office  United States        Chester
# 701    Dl-13600      Dorris liebe    Corporate  United States      Cleveland
# 702    AS-10285  Alejandro Savely    Corporate  United States        Seattle
# 703    JK-15370        Jay Kimmel     Consumer  United States     Long Beach
# 704    BN-11470      Brad Norvell    Corporate  United States           Cary
# ..          ...               ...          ...            ...            ...
# 795    RH-19495       Rick Hansen     Consumer  United States      Rochester
# 796    DB-13120      David Bremer    Corporate  United States      Rochester
# 797    DB-13120      David Bremer    Corporate  United States      Rochester
# 798    DB-13120      David Bremer    Corporate  United States      Rochester
# 799    CD-11920       Carlos Daly     Consumer  United States  Lake Elsinore
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 700  ...       19013     East  OFF-BI-10001982  Office Supplies      Binders
# 701  ...       44105     East  FUR-FU-10002960        Furniture  Furnishings
# 702  ...       98103     West  FUR-FU-10003394        Furniture  Furnishings
# 703  ...       90805     West  FUR-TA-10002774        Furniture       Tables
# 704  ...       27511    South  OFF-PA-10001800  Office Supplies        Paper
# ..   ...         ...      ...              ...              ...          ...
# 795  ...       55901  Central  OFF-BI-10000546  Office Supplies      Binders
# 796  ...       14609     East  OFF-PA-10000176  Office Supplies        Paper
# 797  ...       14609     East  OFF-PA-10002365  Office Supplies        Paper
# 798  ...       14609     East  OFF-LA-10002271  Office Supplies       Labels
# 799  ...       92530     West  FUR-CH-10002647        Furniture       Chairs
#
#                                           Product Name    Sales  Quantity  \
# 700         Wilson Jones Custom Binder Spines & Labels    4.896         3
# 701         Eldon 200 Class Desk Accessories, Burgundy   15.072         3
# 702             Tenex "The Solids" Textured Chair Mats  209.880         3
# 703                         Laminate Occasional Tables  369.912         3
# 704                                          Xerox 220   10.368         2
# ..                                                 ...      ...       ...
# 795                              Avery Durable Binders   20.160         7
# 796                                         Xerox 1887  132.790         7
# 797                                         Xerox 1967   12.960         2
# 798  Smead Alpha-Z Color-Coded Second Alphabetical ...   21.560         7
# 799         Situations Contoured Folding Chairs, 4/Set  283.920         5
#
#      Discount   Profit
# 700       0.7  -3.4272
# 701       0.2   4.1448
# 702       0.0  35.6796
# 703       0.2 -13.8717
# 704       0.2   3.6288
# ..        ...      ...
# 795       0.0   9.8784
# 796       0.0  63.7392
# 797       0.0   6.2208
# 798       0.0  10.3488
# 799       0.2  17.7450
#
# [100 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 800     801  CA-2017-105809   2/20/2017   2/23/2017     First Class
# 801     802  CA-2017-105809   2/20/2017   2/23/2017     First Class
# 802     803  CA-2016-136133   8/18/2016   8/23/2016    Second Class
# 803     804  CA-2016-115504   3/12/2016   3/17/2016  Standard Class
# 804     805  CA-2017-135783   4/22/2017   4/24/2017     First Class
# ..      ...             ...         ...         ...             ...
# 895     896  CA-2016-105494  11/10/2016  11/12/2016     First Class
# 896     897  CA-2016-140634   10/3/2016   10/6/2016    Second Class
# 897     898  CA-2014-144407    9/9/2014   9/15/2014  Standard Class
# 898     899  CA-2017-160983  10/29/2017  10/31/2017    Second Class
# 899     900  US-2016-114622   4/10/2016   4/12/2016     First Class
#
#     Customer ID        Customer Name    Segment        Country           City  \
# 800    HW-14935      Helen Wasserman  Corporate  United States      San Diego
# 801    HW-14935      Helen Wasserman  Corporate  United States      San Diego
# 802    HW-14935      Helen Wasserman  Corporate  United States  New York City
# 803    MC-18130          Mike Caudle  Corporate  United States         Monroe
# 804    GM-14440          Gary McGarr   Consumer  United States  San Francisco
# ..          ...                  ...        ...            ...            ...
# 895    PC-18745       Pamela Coakley  Corporate  United States  San Francisco
# 896    HL-15040         Hunter Lopez   Consumer  United States        Houston
# 897    MS-17365  Maribeth Schnelling   Consumer  United States        Detroit
# 898    GB-14530          George Bell  Corporate  United States         Auburn
# 899    JR-16210        Justin Ritter  Corporate  United States    Springfield
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 800  ...       92105     West  FUR-FU-10004090        Furniture  Furnishings
# 801  ...       92105     West  TEC-PH-10001580       Technology       Phones
# 802  ...       10024     East  OFF-AP-10000576  Office Supplies   Appliances
# 803  ...       71203    South  OFF-PA-10003953  Office Supplies        Paper
# 804  ...       94122     West  FUR-FU-10000794        Furniture  Furnishings
# ..   ...         ...      ...              ...              ...          ...
# 895  ...       94122     West  OFF-BI-10003364  Office Supplies      Binders
# 896  ...       77095  Central  OFF-EN-10001099  Office Supplies    Envelopes
# 897  ...       48227  Central  OFF-LA-10003923  Office Supplies       Labels
# 898  ...       13021     East  OFF-PA-10002250  Office Supplies        Paper
# 899  ...       45503     East  OFF-BI-10004716  Office Supplies      Binders
#
#                                           Product Name    Sales  Quantity  \
# 800      Executive Impressions 14" Contract Wall Clock   22.230         1
# 801  Logitech Mobile Speakerphone P710e - speaker p...  215.968         2
# 802                     Belkin 7 Outlet SurgeMaster II  355.320         9
# 803                                          Xerox 218   12.960         2
# 804      Eldon Stackable Tray, Side-Load, Legal, Smoke   18.280         2
# ..                                                 ...      ...       ...
# 895                           Binding Machine Supplies   70.008         3
# 896                                    Staple envelope   15.648         2
# 897             Alphabetical Labels for Top Tab Filing  103.600         7
# 898                             Things To Do Today Pad   46.960         8
# 899  Wilson Jones Hanging Recycled Pressboard Data ...    8.904         2
#
#      Discount   Profit
# 800       0.0   7.3359
# 801       0.2  18.8972
# 802       0.0  99.4896
# 803       0.0   6.2208
# 804       0.0   6.2152
# ..        ...      ...
# 895       0.2  24.5028
# 896       0.2   5.0856
# 897       0.0  51.8000
# 898       0.0  22.5408
# 899       0.7  -6.5296
#
# [100 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 900     901  CA-2017-150959  11/11/2017  11/13/2017     First Class
# 901     902  CA-2017-150959  11/11/2017  11/13/2017     First Class
# 902     903  CA-2017-132353   9/15/2017   9/17/2017     First Class
# 903     904  CA-2016-130477    4/8/2016   4/12/2016  Standard Class
# 904     905  CA-2016-130477    4/8/2016   4/12/2016  Standard Class
# ..      ...             ...         ...         ...             ...
# 995     996  CA-2014-117639   5/21/2014   5/25/2014  Standard Class
# 996     997  CA-2015-162537  10/28/2015   11/3/2015  Standard Class
# 997     998  CA-2015-162537  10/28/2015   11/3/2015  Standard Class
# 998     999  CA-2015-162537  10/28/2015   11/3/2015  Standard Class
# 999    1000  CA-2015-162537  10/28/2015   11/3/2015  Standard Class
#
#     Customer ID     Customer Name    Segment        Country            City  \
# 900    TD-20995     Tamara Dahlen   Consumer  United States         Garland
# 901    TD-20995     Tamara Dahlen   Consumer  United States         Garland
# 902    DB-13060       Dave Brooks   Consumer  United States         Chicago
# 903    LC-17140      Logan Currie   Consumer  United States     Los Angeles
# 904    LC-17140      Logan Currie   Consumer  United States     Los Angeles
# ..          ...               ...        ...            ...             ...
# 995    MW-18235  Mitch Willingham  Corporate  United States  Virginia Beach
# 996    RD-19585          Rob Dowd   Consumer  United States       Henderson
# 997    RD-19585          Rob Dowd   Consumer  United States       Henderson
# 998    RD-19585          Rob Dowd   Consumer  United States       Henderson
# 999    RD-19585          Rob Dowd   Consumer  United States       Henderson
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 900  ...       75043  Central  OFF-LA-10001045  Office Supplies       Labels
# 901  ...       75043  Central  OFF-BI-10001510  Office Supplies      Binders
# 902  ...       60653  Central  TEC-PH-10004536       Technology       Phones
# 903  ...       90032     West  OFF-PA-10002947  Office Supplies        Paper
# 904  ...       90032     West  OFF-ST-10002583  Office Supplies      Storage
# ..   ...         ...      ...              ...              ...          ...
# 995  ...       23464    South  TEC-PH-10001530       Technology       Phones
# 996  ...       42420    South  OFF-EN-10003862  Office Supplies    Envelopes
# 997  ...       42420    South  OFF-ST-10004258  Office Supplies      Storage
# 998  ...       42420    South  FUR-FU-10002885        Furniture  Furnishings
# 999  ...       42420    South  FUR-FU-10001918        Furniture  Furnishings
#
#                                           Product Name    Sales  Quantity  \
# 900  Permanent Self-Adhesive File Folder Labels for...   10.440         5
# 901          Deluxe Heavy-Duty Vinyl Round Ring Binder   18.336         4
# 902                           Avaya 5420 Digital phone  323.976         3
# 903                                         Xerox 1923   20.040         3
# 904                  Fellowes Neat Ideas Storage Cubes   64.960         2
# ..                                                 ...      ...       ...
# 995                     Plantronics Voyager Pro Legend  617.970         3
# 996                 Laser & Ink Jet Business Envelopes   10.670         1
# 997                         Portable Personal File Box   36.630         3
# 998              Magna Visual Magnetic Picture Hangers   24.100         5
# 999  C-Line Cubicle Keepers Polyproplyene Holder Wi...   33.110         7
#
#      Discount    Profit
# 900       0.2    3.3930
# 901       0.8  -32.0880
# 902       0.2   20.2485
# 903       0.0    9.6192
# 904       0.0    2.5984
# ..        ...       ...
# 995       0.0  173.0316
# 996       0.0    4.9082
# 997       0.0    9.8901
# 998       0.0    9.1580
# 999       0.0   12.9129
#
# [100 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1000    1001  CA-2016-155488  11/13/2016  11/17/2016  Standard Class
# 1001    1002  CA-2015-124891   7/31/2015   7/31/2015        Same Day
# 1002    1003  CA-2015-124891   7/31/2015   7/31/2015        Same Day
# 1003    1004  CA-2015-124891   7/31/2015   7/31/2015        Same Day
# 1004    1005  CA-2015-126445   8/27/2015   8/31/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 1095    1096  CA-2017-160423   1/21/2017   1/26/2017  Standard Class
# 1096    1097  CA-2017-160423   1/21/2017   1/26/2017  Standard Class
# 1097    1098  CA-2014-159338   6/25/2014   6/28/2014     First Class
# 1098    1099  CA-2016-107216   6/14/2016   6/17/2016     First Class
# 1099    1100  CA-2016-107216   6/14/2016   6/17/2016     First Class
#
#      Customer ID    Customer Name      Segment        Country           City  \
# 1000    FM-14290     Frank Merwin  Home Office  United States      Vancouver
# 1001    RH-19495      Rick Hansen     Consumer  United States  New York City
# 1002    RH-19495      Rick Hansen     Consumer  United States  New York City
# 1003    RH-19495      Rick Hansen     Consumer  United States  New York City
# 1004    RA-19945        Ryan Akin     Consumer  United States       Murrieta
# ...          ...              ...          ...            ...            ...
# 1095    PS-19045  Penelope Sewall  Home Office  United States      Charlotte
# 1096    PS-19045  Penelope Sewall  Home Office  United States      Charlotte
# 1097    NS-18640     Noel Staavos    Corporate  United States    Los Angeles
# 1098    PV-18985    Paul Van Hugh  Home Office  United States  San Francisco
# 1099    PV-18985    Paul Van Hugh  Home Office  United States  San Francisco
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 1000  ...       98661    West  OFF-AR-10002956  Office Supplies          Art
# 1001  ...       10024    East  TEC-AC-10003033       Technology  Accessories
# 1002  ...       10024    East  FUR-TA-10002903        Furniture       Tables
# 1003  ...       10024    East  OFF-PA-10004621  Office Supplies        Paper
# 1004  ...       92563    West  OFF-ST-10000046  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 1095  ...       28205   South  OFF-ST-10004340  Office Supplies      Storage
# 1096  ...       28205   South  OFF-BI-10004001  Office Supplies      Binders
# 1097  ...       90049    West  FUR-TA-10004147        Furniture       Tables
# 1098  ...       94122    West  OFF-AR-10001545  Office Supplies          Art
# 1099  ...       94122    West  FUR-FU-10000206        Furniture  Furnishings
#
#                                            Product Name     Sales  Quantity  \
# 1000     Boston 16801 Nautilus Battery Pencil Sharpener    44.020         2
# 1001  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650         7
# 1002            Bevis Round Bullnose 29" High Table Top  1090.782         7
# 1003                                          Xerox 212    19.440         3
# 1004                   Fellowes Super Stor/Drawer Files   484.650         3
# ...                                                 ...       ...       ...
# 1095                   Fellowes Mobile File Cart, Black   348.208         7
# 1096                     GBC Recycled VeloBinder Covers    35.784         7
# 1097                             Hon 4060 Series Tables   447.840         5
# 1098                                         Newell 326     7.040         4
# 1099  GE General Purpose, Extra Long Life, Showcase ...     8.730         3
#
#       Discount    Profit
# 1000       0.0   11.4452
# 1001       0.0  762.1845
# 1002       0.4 -290.8752
# 1003       0.0    9.3312
# 1004       0.0   92.0835
# ...        ...       ...
# 1095       0.2   30.4682
# 1096       0.7  -28.6272
# 1097       0.2   11.1960
# 1098       0.0    2.0416
# 1099       0.0    4.1031
#
# [100 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1100    1101  CA-2016-107216   6/14/2016   6/17/2016     First Class
# 1101    1102  CA-2016-107216   6/14/2016   6/17/2016     First Class
# 1102    1103  US-2017-145863   4/21/2017   4/27/2017  Standard Class
# 1103    1104  US-2017-145863   4/21/2017   4/27/2017  Standard Class
# 1104    1105  CA-2016-112340  10/21/2016  10/27/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 1195    1196  US-2015-130519   9/15/2015   9/15/2015        Same Day
# 1196    1197  US-2015-130519   9/15/2015   9/15/2015        Same Day
# 1197    1198  CA-2016-130946    4/8/2016   4/12/2016  Standard Class
# 1198    1199  CA-2016-130946    4/8/2016   4/12/2016  Standard Class
# 1199    1200  CA-2016-130946    4/8/2016   4/12/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 1100    PV-18985     Paul Van Hugh  Home Office  United States  San Francisco
# 1101    PV-18985     Paul Van Hugh  Home Office  United States  San Francisco
# 1102    RP-19390      Resi Pölking     Consumer  United States        Houston
# 1103    RP-19390      Resi Pölking     Consumer  United States        Houston
# 1104    NM-18520      Neoma Murray     Consumer  United States      Riverside
# ...          ...               ...          ...            ...            ...
# 1195    NG-18355        Nat Gilpin    Corporate  United States  Coral Springs
# 1196    NG-18355        Nat Gilpin    Corporate  United States  Coral Springs
# 1197    ZC-21910  Zuschuss Carroll     Consumer  United States        Houston
# 1198    ZC-21910  Zuschuss Carroll     Consumer  United States        Houston
# 1199    ZC-21910  Zuschuss Carroll     Consumer  United States        Houston
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 1100  ...       94122     West  TEC-AC-10001013       Technology  Accessories
# 1101  ...       94122     West  OFF-AR-10002255  Office Supplies          Art
# 1102  ...       77041  Central  OFF-BI-10004140  Office Supplies      Binders
# 1103  ...       77041  Central  OFF-BI-10002049  Office Supplies      Binders
# 1104  ...       92503     West  OFF-PA-10001892  Office Supplies        Paper
# ...   ...         ...      ...              ...              ...          ...
# 1195  ...       33065    South  OFF-ST-10001321  Office Supplies      Storage
# 1196  ...       33065    South  FUR-FU-10003394        Furniture  Furnishings
# 1197  ...       77041  Central  TEC-AC-10001990       Technology  Accessories
# 1198  ...       77041  Central  FUR-CH-10004540        Furniture       Chairs
# 1199  ...       77041  Central  OFF-BI-10004995  Office Supplies      Binders
#
#                                            Product Name     Sales  Quantity  \
# 1100        Logitech ClearChat Comfort/USB Headset H390    29.290         1
# 1101                                         Newell 346     8.640         3
# 1102                            Avery Non-Stick Binders     2.694         3
# 1103                          UniKeep View Case Binders     2.934         3
# 1104  Rediform Wirebound "Phone Memo" Message Book, ...    22.920         3
# ...                                                 ...       ...       ...
# 1195        Decoflex Hanging Personal Folder File, Blue    24.672         2
# 1196             Tenex "The Solids" Textured Chair Mats    55.968         1
# ...
# 9697    9698  CA-2016-122511   3/11/2016   3/11/2016        Same Day
# 9698    9699  CA-2017-154116  12/15/2017  12/19/2017  Standard Class
# 9699    9700  CA-2017-154116  12/15/2017  12/19/2017  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 9600    EB-13705        Ed Braxton    Corporate  United States
# 9601    JP-15520     Jeremy Pistek     Consumer  United States
# 9602    TD-20995     Tamara Dahlen     Consumer  United States
# 9603    DM-13345     Denise Monton    Corporate  United States
# 9604    EG-13900       Emily Grady     Consumer  United States
# ...          ...               ...          ...            ...
# 9695    SC-20695     Steve Chapman    Corporate  United States
# 9696    HK-14890  Heather Kirkland    Corporate  United States
# 9697    BT-11485       Brad Thomas  Home Office  United States
# 9698    KM-16660      Khloe Miller     Consumer  United States
# 9699    KM-16660      Khloe Miller     Consumer  United States
#
#                 City  ... Postal Code   Region       Product ID  \
# 9600       Mansfield  ...       76063  Central  OFF-PA-10003848
# 9601       Jonesboro  ...       72401    South  OFF-PA-10001357
# 9602  Virginia Beach  ...       23464    South  OFF-SU-10004737
# 9603       Rochester  ...       14609     East  FUR-TA-10003715
# 9604      Chesapeake  ...       23320    South  OFF-AP-10003099
# ...              ...  ...         ...      ...              ...
# 9695     Springfield  ...       45503     East  OFF-AP-10002892
# 9696         Detroit  ...       48234  Central  OFF-LA-10003930
# 9697    Philadelphia  ...       19140     East  FUR-FU-10001037
# 9698       Inglewood  ...       90301     West  OFF-PA-10004569
# 9699       Inglewood  ...       90301     West  OFF-AP-10000027
#
#              Category Sub-Category  \
# 9600  Office Supplies        Paper
# 9601  Office Supplies        Paper
# 9602  Office Supplies     Supplies
# 9603        Furniture       Tables
# 9604  Office Supplies   Appliances
# ...               ...          ...
# 9695  Office Supplies   Appliances
# 9696  Office Supplies       Labels
# 9697        Furniture  Furnishings
# 9698  Office Supplies        Paper
# 9699  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 9600                                         Xerox 1997   41.472         8
# 9601                                         Xerox 1886  239.500         5
# 9602          Acme Design Stainless Steel Bent Scissors   34.200         5
# 9603            Hon 2111 Invitation Series Corner Table  376.866         3
# 9604                        Eureka Hand Vacuum, Bagless  197.720         4
# ...                                                 ...      ...       ...
# 9695                   Belkin F5C206VTEL 6 Outlet Surge   73.536         4
# 9696  Dot Matrix Printer Tape Reel Labels, White, 50...  491.550         5
# 9697     DAX Charcoal/Nickel-Tone Document Frame, 5 x 7   30.336         4
# 9698  Wirebound Message Books, Two 4 1/4" x 5" Forms...   22.830         3
# 9699                         Hoover Commercial SteamVac   54.320         4
#
#       Discount    Profit
# 9600       0.2   14.5152
# 9601       0.0  114.9600
# 9602       0.0    9.2340
# 9603       0.4 -213.5574
# 9604       0.0   55.3616
# ...        ...       ...
# 9695       0.2    9.1920
# 9696       0.0  240.8595
# 9697       0.2    9.4800
# 9698       0.0   10.7301
# 9699       0.0   16.2960
#
# [100 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9700    9701  CA-2017-154116  12/15/2017  12/19/2017  Standard Class
# 9701    9702  CA-2016-105291  10/30/2016   11/4/2016  Standard Class
# 9702    9703  CA-2017-147032   7/31/2017    8/4/2017  Standard Class
# 9703    9704  CA-2017-147032   7/31/2017    8/4/2017  Standard Class
# 9704    9705  CA-2017-147032   7/31/2017    8/4/2017  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2016-125920   5/21/2016   5/28/2016  Standard Class
# 9796    9797  CA-2015-128608   1/12/2015   1/17/2015  Standard Class
# 9797    9798  CA-2015-128608   1/12/2015   1/17/2015  Standard Class
# 9798    9799  CA-2015-128608   1/12/2015   1/17/2015  Standard Class
# 9799    9800  CA-2015-128608   1/12/2015   1/17/2015  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 9700    KM-16660      Khloe Miller     Consumer  United States
# 9701    SP-20920      Susan Pistek     Consumer  United States
# 9702    LB-16795    Laurel Beltran  Home Office  United States
# 9703    LB-16795    Laurel Beltran  Home Office  United States
# 9704    LB-16795    Laurel Beltran  Home Office  United States
# ...          ...               ...          ...            ...
# 9795    SH-19975     Sally Hughsby    Corporate  United States
# 9796    CS-12490  Cindy Schnelling    Corporate  United States
# 9797    CS-12490  Cindy Schnelling    Corporate  United States
# 9798    CS-12490  Cindy Schnelling    Corporate  United States
# 9799    CS-12490  Cindy Schnelling    Corporate  United States
#
#                  City  ... Postal Code   Region       Product ID  \
# 9700        Inglewood  ...       90301     West  TEC-PH-10000675
# 9701  San Luis Obispo  ...       93405     West  OFF-FA-10003059
# 9702       Wilmington  ...       19805     East  OFF-PA-10003256
# 9703       Wilmington  ...       19805     East  OFF-BI-10003656
# 9704       Wilmington  ...       19805     East  OFF-BI-10002897
# ...               ...  ...         ...      ...              ...
# 9795          Chicago  ...       60610  Central  OFF-BI-10003429
# 9796           Toledo  ...       43615     East  OFF-AR-10001374
# 9797           Toledo  ...       43615     East  TEC-PH-10004977
# 9798           Toledo  ...       43615     East  TEC-PH-10000912
# 9799           Toledo  ...       43615     East  TEC-AC-10000487
#
#              Category Sub-Category  \
# 9700       Technology       Phones
# 9701  Office Supplies    Fasteners
# 9702  Office Supplies        Paper
# 9703  Office Supplies      Binders
# 9704  Office Supplies      Binders
# ...               ...          ...
# 9795  Office Supplies      Binders
# 9796  Office Supplies          Art
# 9797       Technology       Phones
# 9798       Technology       Phones
# 9799       Technology  Accessories
#
#                                            Product Name    Sales  Quantity  \
# 9700                  Panasonic KX TS3282B Corded phone  196.776         3
# 9701                           Assorted Color Push Pins    3.620         2
# 9702         Avery Personal Creations Heavyweight Cards   11.540         1
# 9703        Fellowes PB200 Plastic Comb Binding Machine  849.950         5
# 9704  Black Avery Memo-Size 3-Ring Binder, 5 1/2" x ...   11.010         3
# ...                                                 ...      ...       ...
# 9795  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.798         3
# 9796           BIC Brite Liner Highlighters, Chisel Tip   10.368         2
# 9797                                        GE 30524EE4  235.188         2
# 9798           Anker 24W Portable Micro USB Car Charger   26.376         4
# 9799                SanDisk Cruzer 4 GB USB Flash Drive   10.384         2
#
#       Discount    Profit
# 9700       0.2   14.7582
# 9701       0.0    1.1946
# 9702       0.0    5.5392
# 9703       0.0  390.9770
# 9704       0.0    5.3949
# ...        ...       ...
# 9795       0.8   -5.8869
# 9796       0.2    1.5552
# 9797       0.4  -43.1178
# 9798       0.4    2.6376
# 9799       0.2    2.2066
#
# [100 rows x 21 columns]
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9800    9801  CA-2015-128608  1/12/2015  1/17/2015  Standard Class
# 9801    9802  CA-2017-137918  9/29/2017  10/6/2017  Standard Class
# 9802    9803  CA-2015-122973  7/18/2015  7/20/2015    Second Class
# 9803    9804  CA-2015-122973  7/18/2015  7/20/2015    Second Class
# 9804    9805  CA-2015-122973  7/18/2015  7/20/2015    Second Class
# ...      ...             ...        ...        ...             ...
# 9895    9896  CA-2014-115049  9/26/2014  10/1/2014  Standard Class
# 9896    9897  CA-2014-156342  6/17/2014  6/20/2014    Second Class
# 9897    9898  CA-2016-112830   6/6/2016  6/10/2016  Standard Class
# 9898    9899  CA-2016-112830   6/6/2016  6/10/2016  Standard Class
# 9899    9900  US-2014-117380  3/28/2014   4/3/2014  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 9800    CS-12490   Cindy Schnelling    Corporate  United States
# 9801    JK-15730      Joe Kamberova     Consumer  United States
# 9802    PJ-19015    Pauline Johnson     Consumer  United States
# 9803    PJ-19015    Pauline Johnson     Consumer  United States
# 9804    PJ-19015    Pauline Johnson     Consumer  United States
# ...          ...                ...          ...            ...
# 9895    MM-17920      Michael Moore     Consumer  United States
# 9896    JF-15415  Jennifer Ferguson     Consumer  United States
# 9897    LP-17095          Liz Preis     Consumer  United States
# 9898    LP-17095          Liz Preis     Consumer  United States
# 9899    MP-18175     Mike Pelletier  Home Office  United States
#
#                City  ... Postal Code   Region       Product ID  \
# 9800         Toledo  ...       43615     East  TEC-PH-10002262
# 9801           Lodi  ...       95240     West  OFF-SU-10000898
# 9802  New York City  ...       10024     East  OFF-BI-10004182
# 9803  New York City  ...       10024     East  TEC-PH-10002468
# 9804  New York City  ...       10024     East  FUR-FU-10002364
# ...             ...  ...         ...      ...              ...
# 9895        Chicago  ...       60623  Central  TEC-AC-10004859
# 9896        Chicago  ...       60653  Central  OFF-PA-10001725
# 9897      Fairfield  ...       45014     East  FUR-FU-10004306
# 9898      Fairfield  ...       45014     East  FUR-FU-10004845
# 9899    Springfield  ...       45503     East  FUR-TA-10000198
#
#              Category Sub-Category  \
# 9800       Technology       Phones
# 9801  Office Supplies     Supplies
# 9802  Office Supplies      Binders
# 9803       Technology       Phones
# 9804        Furniture  Furnishings
# ...               ...          ...
# 9895       Technology  Accessories
# 9896  Office Supplies        Paper
# 9897        Furniture  Furnishings
# 9898        Furniture  Furnishings
# 9899        Furniture       Tables
#
#                                            Product Name    Sales  Quantity  \
# 9800     LG Electronics Tone+ HBS-730 Bluetooth Headset  107.118         3
# 9801  Acme Hot Forged Carbon Steel Scissors with Nic...   97.300         7
# 9802                                    Economy Binders    3.328         2
# 9803  Plantronics CS 50-USB - headset - Convertible,...  135.990         1
# 9804       Eldon Expressions Wood Desk Accessories, Oak    7.380         1
# ...                                                 ...      ...       ...
# 9895                 Maxell Pro 80 Minute CD-R, 10/Pack  153.824        11
# 9896                                         Xerox 1892   62.016         2
# 9897                    Electrix Halogen Magnifier Lamp  466.320         3
# 9898        Deflect-o EconoMat Nonstudded, No Bevel Mat   82.640         2
# 9899  Chromcraft Bull-Nose Wood Oval Conference Tabl...  330.588         1
#
#       Discount    Profit
# 9800       0.4  -21.4236
# 9801       0.0   28.2170
# 9802       0.2    1.2064
# 9803       0.0   36.7173
# 9804       0.0    2.1402
# ...        ...       ...
# 9895       0.2   38.4560
# 9896       0.2   22.4808
# 9897       0.2   34.9740
# 9898       0.2    0.0000
# 9899       0.4 -143.2548
#
# [100 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9900    9901  CA-2017-117646   8/21/2017   8/25/2017  Standard Class
# 9901    9902  CA-2017-117646   8/21/2017   8/25/2017  Standard Class
# 9902    9903  CA-2017-117646   8/21/2017   8/25/2017  Standard Class
# 9903    9904  CA-2014-122609  11/12/2014  11/18/2014  Standard Class
# 9904    9905  CA-2014-122609  11/12/2014  11/18/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9900    SC-20845        Sung Chung  Consumer  United States   Louisville  ...
# 9901    SC-20845        Sung Chung  Consumer  United States   Louisville  ...
# 9902    SC-20845        Sung Chung  Consumer  United States   Louisville  ...
# 9903    DP-13000     Darren Powers  Consumer  United States   Carrollton  ...
# 9904    DP-13000     Darren Powers  Consumer  United States   Carrollton  ...
# ...          ...               ...       ...            ...          ...  ...
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# 9900       80027     West  OFF-ST-10000036  Office Supplies      Storage
# 9901       80027     West  FUR-FU-10001037        Furniture  Furnishings
# 9902       80027     West  OFF-PA-10001950  Office Supplies        Paper
# 9903       75007  Central  FUR-FU-10004587        Furniture  Furnishings
# 9904       75007  Central  TEC-AC-10002567       Technology  Accessories
# ...          ...      ...              ...              ...          ...
# 9989       33180    South  FUR-FU-10001889        Furniture  Furnishings
# 9990       92627     West  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627     West  TEC-PH-10003645       Technology       Phones
# 9992       92627     West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683     West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 9900  Recycled Data-Pak for Archival Bound Computer ...  237.096         3
# 9901     DAX Charcoal/Nickel-Tone Document Frame, 5 x 7   22.752         3
# 9902  Southworth 25% Cotton Antique Laid Paper & Env...    6.672         1
# 9903  GE General Use Halogen Bulbs, 100 Watts, 1 Bul...   25.128         3
# 9904                Logitech G602 Wireless Gaming Mouse  127.984         2
# ...                                                 ...      ...       ...
# 9989                             Ultra Door Pull Handle   25.248         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       Discount   Profit
# 9900       0.2  20.7459
# 9901       0.2   7.1100
# 9902       0.2   2.0850
# 9903       0.6  -6.9102
# 9904       0.2  25.5968
# ...        ...      ...
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [94 rows x 21 columns]

# %% [markdown]
# **🧩 Reading Excel Files**

# %%
# Import pandas library (make sure you've imported it before running this code)
import pandas as pd

# Define the path to the Excel file containing the dataset.
# Update this path if the file is stored elsewhere on your system.
people_basic = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\people_basic_data.xlsx"

# Read the Excel file into a pandas DataFrame.
# pd.read_excel() automatically detects the sheet unless specified using 'sheet_name' parameter.
df_exl = pd.read_excel(people_basic)

# Display the first 5 rows of the DataFrame to get a quick overview of the data.
# This helps verify that the file was read correctly and understand the structure of the dataset.
print(df_exl.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **🧩 Reading Excel Files (Sheets)**

# %%
# Import pandas library — required for data manipulation and reading Excel files
import pandas as pd

# Define the path to the Excel file.
# The 'r' before the string makes it a raw string, so backslashes are treated literally.
people_basic_sheet = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\people_basic_data.xlsx"

# Read a specific sheet ("peoplebasic") from the Excel file into a pandas DataFrame.
# The 'sheet_name' parameter specifies which sheet to load — useful when the file contains multiple sheets.
df_ex_sheet = pd.read_excel(people_basic_sheet, sheet_name="peoplebasic")

# Print the entire DataFrame to view its contents.
# Be careful: if the dataset is large, this will print all rows.
# You can use df_ex_sheet.head() instead to show only the first 5 rows.
print(df_ex_sheet.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **Multiple Sheets at Once**

# %%
# Import pandas library — used for data analysis and Excel file handling
import pandas as pd

# Define the path to the Excel file containing multiple sheets.
# The 'r' before the string makes it a raw string so backslashes are treated literally.
people_basic_sheet = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\people_basic_data.xlsx"

# Read all sheets from the Excel file into a dictionary of DataFrames.
# Setting sheet_name=None tells pandas to read *every* sheet in the file.
# The resulting object is a dictionary where:
#   - Keys = sheet names
#   - Values = DataFrames containing the data from each sheet
dfs_multi_sheet = pd.read_excel(people_basic_sheet, sheet_name=None)

# Print the keys (sheet names) of the dictionary.
# This shows which sheets were loaded from the Excel file.
print(dfs_multi_sheet.keys())
# Out:
# dict_keys(['peoplebasic'])

# %% [markdown]
# **🧩 Reading JSON Files**

# %%
# Import pandas library — required for handling JSON, Excel, CSV, and other data formats
import pandas as pd

# Define the path to the JSON file.
# The 'r' prefix makes it a raw string literal, so backslashes are treated literally (useful for Windows paths).
sales_json = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\sales_data.json"

# Read the JSON file into a pandas DataFrame.
# pd.read_json() automatically converts JSON structures (like arrays or objects) into tabular format.
# The JSON file should contain a valid structure such as:
# [
#   {"date": "2025-01-01", "sales": 200, "region": "North"},
#   {"date": "2025-01-02", "sales": 250, "region": "South"}
# ]
df_json = pd.read_json(sales_json)

# Display the DataFrame to verify that the JSON data was loaded correctly.
print(df_json)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **🧩 Reading Data from URLs or APIs**

# %%
# Import pandas library — required for reading CSV files and data manipulation
import pandas as pd

# Define the URL of the CSV file.
# This file is hosted online on GitHub and contains the famous Iris dataset.
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

# Read the CSV file directly from the URL into a pandas DataFrame.
# pd.read_csv() can handle both local file paths and URLs.
df = pd.read_csv(url)

# Display the first 5 rows of the DataFrame.
# This gives a quick overview of the dataset's structure and contents.
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import requests

url = "https://data.wa.gov/api/views/f6w7-q2d2/rows.json?accessType=DOWNLOAD"


response = requests.get(url)
invest_data = response.json()

rows = invest_data['data']

columns = [col['name'] for col in invest_data['meta']['view']['columns']]

df = pd.DataFrame(rows, columns=columns)
print(df.head)
# Out:
# <bound method NDFrame.head of                        sid                                    id  position  \
# 0       row-9zmh-kxbg.u7ht  00000000-0000-0000-D2B6-825AE6F8F1CE         0
# 1       row-37k7-e7fd.ke3a  00000000-0000-0000-E2D8-EA9DF85F3D8A         0
# 2       row-6tqu_bbkp-svcy  00000000-0000-0000-F9FE-B94525DD352F         0
# 3       row-a9tb.fs47_7guu  00000000-0000-0000-DBD6-06DE43567716         0
# 4       row-pnnp-rdrk_2tq7  00000000-0000-0000-10FC-57C1DAA2F1DF         0
# ...                    ...                                   ...       ...
# 264623  row-emkp.wbxj-x5if  00000000-0000-0000-4347-29B94EE1B336         0
# 264624  row-vxne.ssid.3q46  00000000-0000-0000-D301-B5935F31BA59         0
# 264625  row-enpg~ga9v-az63  00000000-0000-0000-8683-1D9C52569B86         0
# 264626  row-gii8.hmzj.kysr  00000000-0000-0000-DE47-89235328C85D         0
# 264627  row-csn6.n4ji~h4di  00000000-0000-0000-215B-D56AFB9B3250         0
#
#         created_at created_meta  updated_at updated_meta meta  VIN (1-10)  \
# 0       1760391073         None  1760391201         None  { }  WA1E2AFY8R
# 1       1760391073         None  1760391201         None  { }  WAUUPBFF4J
# 2       1760391073         None  1760391201         None  { }  1N4AZ0CP0F
# 3       1760391073         None  1760391201         None  { }  WA1VAAGE5K
# 4       1760391073         None  1760391201         None  { }  7SAXCAE57N
# ...            ...          ...         ...          ...  ...         ...
# 264623  1760391073         None  1760391251         None  { }  KM8KRDDF7R
# 264624  1760391073         None  1760391251         None  { }  1N4BZ0CPXG
# 264625  1760391073         None  1760391251         None  { }  7SAYGDEE4P
# 264626  1760391073         None  1760391251         None  { }  5YJYGDEE9M
# 264627  1760391073         None  1760391251         None  { }  7SAYGDEE9S
#
#            County  ... Electric Range Base MSRP Legislative District  \
# 0        Thurston  ...             23         0                   22
# 1          Yakima  ...             16         0                   15
# 2            King  ...             84         0                   46
# 3            King  ...            204         0                   11
# 4       Snohomish  ...              0         0                    1
# ...           ...  ...            ...       ...                  ...
# 264623       King  ...              0         0                   45
# 264624       King  ...             84         0                   36
# 264625       King  ...              0         0                   11
# 264626       King  ...              0         0                   48
# 264627       King  ...              0         0                   41
#
#        DOL Vehicle ID             Vehicle Location  \
# 0           263239938   POINT (-122.90787 46.9461)
# 1           318160860  POINT (-120.42083 46.44779)
# 2           184963586  POINT (-122.30253 47.72656)
# 3           259426821  POINT (-122.17743 47.41185)
# 4           208182236   POINT (-122.18384 47.8031)
# ...               ...                          ...
# 264623      274603444  POINT (-122.02054 47.60326)
# 264624      476696867  POINT (-122.40092 47.65908)
# 264625      231020723  POINT (-122.16335 47.53505)
# 264626      139826809  POINT (-122.13158 47.67858)
# 264627      275985356   POINT (-122.1872 47.61001)
#
#                                      Electric Utility 2020 Census Tract  \
# 0                              PUGET SOUND ENERGY INC       53067010910
# 1                                          PACIFICORP       53077940008
# 2        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033000700
# 3       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033029306
# 4                              PUGET SOUND ENERGY INC       53061051922
# ...                                               ...               ...
# 264623  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033032225
# 264624   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033005803
# 264625  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033025602
# 264626  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033022902
# 264627  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033023808
#
#        Counties Congressional Districts  \
# 0          2742                      10
# 1          2746                       4
# 2          3009                       7
# 3          3009                       9
# 4          3213                       1
# ...         ...                     ...
# 264623     3009                       8
# 264624     3009                       7
# 264625     3009                       9
# 264626     3009                       1
# 264627     3009                       9
#
#        WAOFM - GIS - Legislative District Boundary
# 0                                               39
# 1                                               22
# 2                                               48
# 3                                               46
# 4                                                1
# ...                                            ...
# 264623                                          47
# 264624                                          31
# 264625                                          42
# 264626                                          49
# 264627                                          42
#
# [264628 rows x 28 columns]>

# %% [markdown]
# **🧩 Writing (Exporting) Data**

# %%
df_expo = df.to_csv(r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\cleaned\superstore_sales_cleaned.csv", index=False)

print(df_expo)
# Out:
# None

# %% [markdown]
# **Write to Excel**

# %%
# Import pandas library — required for data manipulation and exporting data
import pandas as pd

# Assuming 'df' is the cleaned sales DataFrame that you want to export

# Reset the index of the DataFrame.
# drop=True ensures that the old index is removed and not added as a column.
df_reset = df.reset_index(drop=True)

# Export the cleaned DataFrame to an Excel file.
# The 'index=False' argument prevents the DataFrame's index from being written to the file.
# This saves the DataFrame to the specified path without the index column, which is often not needed in the output.
df_reset.to_excel(r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\cleaned\people_basic_data.xlsx", index=False)

# Print the cleaned DataFrame to verify the changes before saving
print(df_reset)
# Out:
#                        sid                                    id  position  \
# 0       row-9zmh-kxbg.u7ht  00000000-0000-0000-D2B6-825AE6F8F1CE         0
# 1       row-37k7-e7fd.ke3a  00000000-0000-0000-E2D8-EA9DF85F3D8A         0
# 2       row-6tqu_bbkp-svcy  00000000-0000-0000-F9FE-B94525DD352F         0
# 3       row-a9tb.fs47_7guu  00000000-0000-0000-DBD6-06DE43567716         0
# 4       row-pnnp-rdrk_2tq7  00000000-0000-0000-10FC-57C1DAA2F1DF         0
# ...                    ...                                   ...       ...
# 264623  row-emkp.wbxj-x5if  00000000-0000-0000-4347-29B94EE1B336         0
# 264624  row-vxne.ssid.3q46  00000000-0000-0000-D301-B5935F31BA59         0
# 264625  row-enpg~ga9v-az63  00000000-0000-0000-8683-1D9C52569B86         0
# 264626  row-gii8.hmzj.kysr  00000000-0000-0000-DE47-89235328C85D         0
# 264627  row-csn6.n4ji~h4di  00000000-0000-0000-215B-D56AFB9B3250         0
#
#         created_at created_meta  updated_at updated_meta meta  VIN (1-10)  \
# 0       1760391073         None  1760391201         None  { }  WA1E2AFY8R
# 1       1760391073         None  1760391201         None  { }  WAUUPBFF4J
# 2       1760391073         None  1760391201         None  { }  1N4AZ0CP0F
# 3       1760391073         None  1760391201         None  { }  WA1VAAGE5K
# 4       1760391073         None  1760391201         None  { }  7SAXCAE57N
# ...            ...          ...         ...          ...  ...         ...
# 264623  1760391073         None  1760391251         None  { }  KM8KRDDF7R
# 264624  1760391073         None  1760391251         None  { }  1N4BZ0CPXG
# 264625  1760391073         None  1760391251         None  { }  7SAYGDEE4P
# 264626  1760391073         None  1760391251         None  { }  5YJYGDEE9M
# 264627  1760391073         None  1760391251         None  { }  7SAYGDEE9S
#
#            County  ... Electric Range Base MSRP Legislative District  \
# 0        Thurston  ...             23         0                   22
# 1          Yakima  ...             16         0                   15
# 2            King  ...             84         0                   46
# 3            King  ...            204         0                   11
# 4       Snohomish  ...              0         0                    1
# ...           ...  ...            ...       ...                  ...
# 264623       King  ...              0         0                   45
# 264624       King  ...             84         0                   36
# 264625       King  ...              0         0                   11
# 264626       King  ...              0         0                   48
# 264627       King  ...              0         0                   41
#
#        DOL Vehicle ID             Vehicle Location  \
# 0           263239938   POINT (-122.90787 46.9461)
# 1           318160860  POINT (-120.42083 46.44779)
# 2           184963586  POINT (-122.30253 47.72656)
# 3           259426821  POINT (-122.17743 47.41185)
# 4           208182236   POINT (-122.18384 47.8031)
# ...               ...                          ...
# 264623      274603444  POINT (-122.02054 47.60326)
# 264624      476696867  POINT (-122.40092 47.65908)
# 264625      231020723  POINT (-122.16335 47.53505)
# 264626      139826809  POINT (-122.13158 47.67858)
# 264627      275985356   POINT (-122.1872 47.61001)
#
#                                      Electric Utility 2020 Census Tract  \
# 0                              PUGET SOUND ENERGY INC       53067010910
# 1                                          PACIFICORP       53077940008
# 2        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033000700
# 3       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033029306
# 4                              PUGET SOUND ENERGY INC       53061051922
# ...                                               ...               ...
# 264623  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033032225
# 264624   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033005803
# 264625  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033025602
# 264626  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033022902
# 264627  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033023808
#
#        Counties Congressional Districts  \
# 0          2742                      10
# 1          2746                       4
# 2          3009                       7
# 3          3009                       9
# 4          3213                       1
# ...         ...                     ...
# 264623     3009                       8
# 264624     3009                       7
# 264625     3009                       9
# 264626     3009                       1
# 264627     3009                       9
#
#        WAOFM - GIS - Legislative District Boundary
# 0                                               39
# 1                                               22
# 2                                               48
# 3                                               46
# 4                                                1
# ...                                            ...
# 264623                                          47
# 264624                                          31
# 264625                                          42
# 264626                                          49
# 264627                                          42
#
# [264628 rows x 28 columns]

# %% [markdown]
# **Write to JSON**

# %%
# Import pandas library — necessary for data manipulation and file export
import pandas as pd

# Reset the index of the DataFrame.
# drop=True ensures that the old index is not included as a column in the new DataFrame.
df_reset = df.reset_index(drop=True)

# Export the cleaned DataFrame to a JSON file.
# The 'orient' argument is set to 'records', which converts each row into a dictionary format.
# 'indent=2' makes the output more human-readable by adding indents for readability (useful for debugging or sharing).
df_reset.to_json(r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\cleaned\sales_data.json", orient='records', indent=2)

# Print the cleaned DataFrame to verify the changes before saving
print(df_reset)
# Out:
#                        sid                                    id  position  \
# 0       row-9zmh-kxbg.u7ht  00000000-0000-0000-D2B6-825AE6F8F1CE         0
# 1       row-37k7-e7fd.ke3a  00000000-0000-0000-E2D8-EA9DF85F3D8A         0
# 2       row-6tqu_bbkp-svcy  00000000-0000-0000-F9FE-B94525DD352F         0
# 3       row-a9tb.fs47_7guu  00000000-0000-0000-DBD6-06DE43567716         0
# 4       row-pnnp-rdrk_2tq7  00000000-0000-0000-10FC-57C1DAA2F1DF         0
# ...                    ...                                   ...       ...
# 264623  row-emkp.wbxj-x5if  00000000-0000-0000-4347-29B94EE1B336         0
# 264624  row-vxne.ssid.3q46  00000000-0000-0000-D301-B5935F31BA59         0
# 264625  row-enpg~ga9v-az63  00000000-0000-0000-8683-1D9C52569B86         0
# 264626  row-gii8.hmzj.kysr  00000000-0000-0000-DE47-89235328C85D         0
# 264627  row-csn6.n4ji~h4di  00000000-0000-0000-215B-D56AFB9B3250         0
#
#         created_at created_meta  updated_at updated_meta meta  VIN (1-10)  \
# 0       1760391073         None  1760391201         None  { }  WA1E2AFY8R
# 1       1760391073         None  1760391201         None  { }  WAUUPBFF4J
# 2       1760391073         None  1760391201         None  { }  1N4AZ0CP0F
# 3       1760391073         None  1760391201         None  { }  WA1VAAGE5K
# 4       1760391073         None  1760391201         None  { }  7SAXCAE57N
# ...            ...          ...         ...          ...  ...         ...
# 264623  1760391073         None  1760391251         None  { }  KM8KRDDF7R
# 264624  1760391073         None  1760391251         None  { }  1N4BZ0CPXG
# 264625  1760391073         None  1760391251         None  { }  7SAYGDEE4P
# 264626  1760391073         None  1760391251         None  { }  5YJYGDEE9M
# 264627  1760391073         None  1760391251         None  { }  7SAYGDEE9S
#
#            County  ... Electric Range Base MSRP Legislative District  \
# 0        Thurston  ...             23         0                   22
# 1          Yakima  ...             16         0                   15
# 2            King  ...             84         0                   46
# 3            King  ...            204         0                   11
# 4       Snohomish  ...              0         0                    1
# ...           ...  ...            ...       ...                  ...
# 264623       King  ...              0         0                   45
# 264624       King  ...             84         0                   36
# 264625       King  ...              0         0                   11
# 264626       King  ...              0         0                   48
# 264627       King  ...              0         0                   41
#
#        DOL Vehicle ID             Vehicle Location  \
# 0           263239938   POINT (-122.90787 46.9461)
# 1           318160860  POINT (-120.42083 46.44779)
# 2           184963586  POINT (-122.30253 47.72656)
# 3           259426821  POINT (-122.17743 47.41185)
# 4           208182236   POINT (-122.18384 47.8031)
# ...               ...                          ...
# 264623      274603444  POINT (-122.02054 47.60326)
# 264624      476696867  POINT (-122.40092 47.65908)
# 264625      231020723  POINT (-122.16335 47.53505)
# 264626      139826809  POINT (-122.13158 47.67858)
# 264627      275985356   POINT (-122.1872 47.61001)
#
#                                      Electric Utility 2020 Census Tract  \
# 0                              PUGET SOUND ENERGY INC       53067010910
# 1                                          PACIFICORP       53077940008
# 2        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033000700
# 3       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033029306
# 4                              PUGET SOUND ENERGY INC       53061051922
# ...                                               ...               ...
# 264623  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033032225
# 264624   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033005803
# 264625  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033025602
# 264626  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033022902
# 264627  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033023808
#
#        Counties Congressional Districts  \
# 0          2742                      10
# 1          2746                       4
# 2          3009                       7
# 3          3009                       9
# 4          3213                       1
# ...         ...                     ...
# 264623     3009                       8
# 264624     3009                       7
# 264625     3009                       9
# 264626     3009                       1
# 264627     3009                       9
#
#        WAOFM - GIS - Legislative District Boundary
# 0                                               39
# 1                                               22
# 2                                               48
# 3                                               46
# 4                                                1
# ...                                            ...
# 264623                                          47
# 264624                                          31
# 264625                                          42
# 264626                                          49
# 264627                                          42
#
# [264628 rows x 28 columns]

# %% [markdown]
# **🧩 Reading/Writing from SQL (Preview)**

# %%
# import sqlite3
# conn = sqlite3.connect('../datasets/raw/sample.db')

# df = pd.read_sql("SELECT * FROM sales", conn)
# df.to_sql('cleaned_sales', conn, if_exists='replace', index=False)
# conn.close()

# %% [markdown]
# **🧩 Mini Project — “Data I/O Pipeline**
